# %%
from pathlib import Path

# 1. Obtener la ruta absoluta del script actual
script_path = Path("test.ipynb").resolve()
script_path.parent
# Out:
# WindowsPath('C:/Users/Alvaro/Documents/GitHub/Proyecto_ML')

# %%
from ultralytics import YOLO
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# %%
model = YOLO("./modelo_final_visdrone/weights/best.pt")

# %%
img = plt.imread("datasets/VisDrone/images/test/0000011_05068_d_0000008.jpg")
plt.imshow(img)

# %%
result = model.predict(img)
# Out:
# 0: 384x640 20 pedestrians, 5 peoples, 2 bicycles, 1 awning-tricycle, 4 motors, 302.9ms
# Speed: 11.8ms preprocess, 302.9ms inference, 17.2ms postprocess per image at shape (1, 3, 384, 640)

# %%
annotated = result[0].plot()   # array BGR (OpenCV format)

# Mostrar con matplotlib (convierte BGR a RGB)
plt.imshow(annotated[..., ::-1])
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1359.5), np.float64(764.5), np.float64(-0.5))

# %%
img = plt.imread("datasets/data_airsim/rgb/000080.png")
plt.imshow(img)

# %%
result = model.predict(img)
annotated = result[0].plot()   # array BGR (OpenCV format)

# Mostrar con matplotlib (convierte BGR a RGB)
plt.imshow(annotated[..., ::-1])
plt.axis('off')
# Out:
# 0: 640x640 (no detections), 347.3ms
# Speed: 27.0ms preprocess, 347.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# (np.float64(-0.5), np.float64(319.5), np.float64(319.5), np.float64(-0.5))

# %%
model_2 = YOLO("./models/best_VisDrone_kitti.pt")

# %%
img = Image.open("datasets/kitti/images/val/000139.png")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1242x375>

# %%
result = model.predict(img)
annotated = result[0].plot()   # array BGR (OpenCV format)

# Mostrar con matplotlib (convierte BGR a RGB)
plt.imshow(annotated[..., ::-1])
plt.axis('off')
# Out:
# 0: 224x640 1 car, 1 van, 1 truck, 237.4ms
# Speed: 2.4ms preprocess, 237.4ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 640)
# (np.float64(-0.5), np.float64(1241.5), np.float64(374.5), np.float64(-0.5))

# %%
result = model_2.predict(img)
annotated = result[0].plot()   # array BGR (OpenCV format)

# Mostrar con matplotlib (convierte BGR a RGB)
plt.imshow(annotated[..., ::-1])
plt.axis('off')
# Out:
# 0: 224x640 2 cars, 1 van, 1 truck, 128.5ms
# Speed: 0.8ms preprocess, 128.5ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 640)
# (np.float64(-0.5), np.float64(1241.5), np.float64(374.5), np.float64(-0.5))

# %%
depth = cv2.imread("datasets/kitti/images/val/000139.png", cv2.IMREAD_UNCHANGED)
plt.imshow(depth, cmap='gray')
plt.colorbar()
plt.show()

# %%
model.names
# Out:
# {0: 'pedestrian',
#  1: 'people',
#  2: 'bicycle',
#  3: 'car',
#  4: 'van',
#  5: 'truck',
#  6: 'tricycle',
#  7: 'awning-tricycle',
#  8: 'bus',
#  9: 'motor'}

# %%
model_2.names
# Out:
# {0: 'car',
#  1: 'van',
#  2: 'truck',
#  3: 'pedestrian',
#  4: 'Person_sitting',
#  5: 'cyclist',
#  6: 'tram',
#  7: 'misc'}

# %%
img = plt.imread("datasets/data_airsim/rgb/000285.png")
plt.imshow(img)

# %%
# Si tiene 4 canales → convertir a 3
if img.shape[-1] == 4:
    img = img[..., :3]   # eliminar alpha

result = model.predict(img)
annotated = result[0].plot()   # array BGR (OpenCV format)

# Mostrar con matplotlib (convierte BGR a RGB)
plt.imshow(annotated[..., ::-1])
plt.axis('off')
# Out:
# 0: 384x640 (no detections), 559.0ms
# Speed: 55.3ms preprocess, 559.0ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
# (np.float64(-0.5), np.float64(1917.5), np.float64(1077.5), np.float64(-0.5))

# %%
model = YOLO("models/best_Visdrone_Airsim.pt")

img = plt.imread("datasets/prueba.jpg")
plt.imshow(img)

# Si tiene 4 canales → convertir a 3
if img.shape[-1] == 4:
    img = img[..., :3]   # eliminar alpha

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

result = model.predict(img_rgb)
annotated = result[0].plot()   # array BGR (OpenCV format)

# Mostrar con matplotlib (convierte BGR a RGB)
plt.imshow(annotated[..., ::-1])
plt.axis('off')
# Out:
# 0: 384x640 (no detections), 207.2ms
# Speed: 30.9ms preprocess, 207.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# (np.float64(-0.5), np.float64(1279.5), np.float64(719.5), np.float64(-0.5))

# %%
img =Image.open("datasets/data_airsim/rgb/000285.png")
img.size
# Out:
# (320, 320)

# %%
model = YOLO("models/best_Airsim.pt")

img = plt.imread("datasets/prueba.jpg")
plt.imshow(img)

# Si tiene 4 canales → convertir a 3
if img.shape[-1] == 4:
    img = img[..., :3]   # eliminar alpha

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

result = model.predict(img_rgb)
annotated = result[0].plot()   # array BGR (OpenCV format)

# Mostrar con matplotlib (convierte BGR a RGB)
plt.imshow(annotated[..., ::-1])
plt.axis('off')
# Out:
# 0: 384x640 1 Coche, 5 Casas, 4 Arbols, 128.0ms
# Speed: 37.3ms preprocess, 128.0ms inference, 16.4ms postprocess per image at shape (1, 3, 384, 640)
# (np.float64(-0.5), np.float64(1279.5), np.float64(719.5), np.float64(-0.5))
